# %% [markdown]
# <a href="https://colab.research.google.com/github/anakaren53/An-lisis-de-datos-violencia-M-xico/blob/main/Radiograf%C3%ADa_Criminal_en_M%C3%A9xico_(2015_2023).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Base de datos

# %% [markdown]
# Importar la base de datos
# https://www.kaggle.com/datasets/elanderos/official-crime-stats-mexico-2015-2023

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("elanderos/official-crime-stats-mexico-2015-2023")

print("Path to dataset files:", path)

#Importar el pandas
import pandas as pd
df = pd.read_csv('mexico_crime.csv')
df.head()
# Out:
# Using Colab cache for faster access to the 'official-crime-stats-mexico-2015-2023' dataset.
# Path to dataset files: /kaggle/input/official-crime-stats-mexico-2015-2023
#    year  entity_code          entity        affected_legal_good type_of_crime  \
# 0  2015            1  Aguascalientes  Life and bodily integrity      Homicide
# 1  2015            1  Aguascalientes  Life and bodily integrity      Homicide
# 2  2015            1  Aguascalientes  Life and bodily integrity      Homicide
# 3  2015            1  Aguascalientes  Life and bodily integrity      Homicide
# 4  2015            1  Aguascalientes  Life and bodily integrity      Homicide
#
#        subtype_of_crime              modality    month  count
# 0  Intentional Homicide          With firearm  January      3
# 1  Intentional Homicide     With sharp weapon  January      1
# 2  Intentional Homicide  With another element  January      0
# 3  Intentional Homicide         Not specified  January      2
# ...

# %%
# Renombra las columnas a español
Columnas = {
    'year': 'Año',
    'entity_code': 'Id_estado',
    'entity': 'Estado',
    'affected_legal_good': 'Bien_juridico_afectado',
    'type_of_crime': 'Tipo_delito',
    'subtype_of_crime': 'Subtipo_delito',
    'modality': 'Modalidad_delito',
    'month': 'Mes',
    'count': 'Cantidad'
}

df_analisis  = df.rename(columns=Columnas)

#affected_legal_good contenido en español
Bien_juridico_afectado = {
    'Heritage or property': 'Patrimonio',
    'Life and bodily integrity': 'Vida e integridad física',
    'Other legal interests affected (from common law)': 'Otros bienes jurídicos afectados (del fuero común)',
    'Personal freedom': 'Libertad personal',
    'Sexual freedom and security': 'Libertad y seguridad sexual',
    'Society': 'La sociedad',
    'The family': 'La familia'
}

df_analisis['Bien_juridico_afectado'] = df_analisis['Bien_juridico_afectado'].map(Bien_juridico_afectado)

#affected_legal_good contenido en español
Tipo_delito = {
    'Abduction': 'Secuestro',
    'Abortion': 'Aborto',
    'Aggravated rape': 'Violación agravada',
    'Burglary': 'Robo con allanamiento de morada',
    'Child trafficking': 'Tráfico de niños',
    'Corruption of minors': 'Corrupción de menores',
    'Counterfeiting': 'Falsificación de monedas y bienes',
    'Crimes committed by public officials': 'Crimenes cometidos por oficiales publicos',
    'Dispossession': 'Despojo de bienes',
    'Domestic violence': 'Violencia domestica',
    'Drug trafficking (small-scale)': 'Tráfico de drogas (pequeños)',
    'Electoral crimes': 'Crimenes electorales',
    'Embezzlement': 'Malversación de fondos',
    'Environmental crimes': 'Crimenes ambientales',
    'Extortion': 'Extorsión',
    'Feminicide': 'Feminicidio',
    'Forgery': 'Falsificación de documentos',
    'Fraud': 'Fraude',
    'Gender-based violence in all its forms other than domestic violence': 'Violencia de género en todas sus formas excepto violencia domestica',
    'Homicide': 'Homicidio',
    'Human trafficking': 'Trata de personas',
    'Incest': 'Incesto',
    'Injuries': 'Lesiones',
    'Kidnapping': 'Secuestro',
    'Non-compliance with family support obligations': 'Incumplimiento de obligaciones de manutención familiar',
    'Other common law crimes': 'Otros delitos de derecho común',
    'Other crimes against heritage or property': 'Otros delitos contra el patrimonio o la propiedad',
    'Other crimes against life and bodily integrity': 'Otros delitos contra la vida y la integridad corporal',
    'Other crimes against personal freedom': 'Otros delitos contra la libertad personal',
    'Other crimes against sexual freedom and security': 'Otros delitos contra la libertad y seguridad sexual',
    'Other crimes against society': 'Otros delitos contra la sociedad',
    'Other crimes against the family': 'Otros delitos contra la familia',
    'Prisoner escape': 'Evasión de presos',
    'Property damage': 'Daños a la propiedad',
    'Robbery': 'Robo',
    'Sexual abuse': 'Abuso sexual',
    'Sexual harassment': 'Acoso sexual',
    'Simple rape': 'Violación',
    'Threats': 'Amenazas'
}
df_analisis['Tipo_delito'] = df_analisis['Tipo_delito'].map(Tipo_delito)

Subtipo_delito = {
    'Abduction': 'Secuestro',
    'Abortion': 'Aborto',
    'Auto Parts Theft': 'Robo de autopartes',
    'Bank Institution Robbery': 'Robo a institución bancaria',
    'Breach of Trust': 'Abuso de confianza',
    'Business Robbery': 'Robo a negocio',
    'Carrier Theft': 'Robo a transportista',
    'Cattle Theft': 'Abigeato(Robo de ganado o animales domésticos)',
    'Child Trafficking': 'Tráfico de menores',
    'Corruption of minors': 'Corrupción de menores',
    'Crimes committed by public servants': 'Delitos cometidos por servidores públicos',
    'Dispossession': 'Despojo de bienes',
    'Drug dealing': 'Narcomenudeo',
    'Electoral crimes': 'Delitos electorales',
    'Environmental crimes': 'Delitos ambientales',
    'Equivalent Rape': 'Violación equiparada',
    'Extortion': 'Extorsión',
    'Falsity': 'Falsedad',
    'Family Violence': 'Violencia familiar',
    'Feminicide': 'Feminicidio',
    'Forgery': 'Falsificación',
    'Fraud': 'Fraude',
    'Gender Violence in all its forms other than family violence': 'Violencia de género en todas sus modalidades distinta a la violencia familiar',
    'Home Burglary': 'Robo a casa habitación',
    'Housebreaking': 'Allanamiento de morada',
    'Human Trafficking': 'Trata de personas',
    'Incest': 'Incesto',
    'Individual Public Transport Robbery': 'Robo a pasajero a bordo de transporte público individual',
    'Individual Transportation Robbery': 'Robo a pasajero a bordo de transporte individual',
    'Intentional Homicide': 'Homicidio intencional',
    'Intentional Injury': 'Lesiones intencionales',
    'Kidnapping': 'Secuestro',
    'Machinery Theft': 'Robo de maquinaria',
    'Manslaughter': 'Homicidio culposo',
    'Non-compliance with family assistance obligations': 'Incumplimiento de las obligaciones de manutención familiar',
    'Other common-law crimes': 'Otros delitos de derecho común',
    'Other crimes against life and bodily integrity': 'Otros delitos contra la vida y la integridad corporal',
    'Other crimes against personal freedom': 'Otros delitos contra la libertad personal',
    'Other crimes against property': 'Otros delitos contra la propiedad',
    'Other crimes against sexual freedom and security': 'Otros delitos contra la libertad y la seguridad sexual',
    'Other crimes against society': 'Otros delitos contra la sociedad',
    'Other crimes against the family': 'Otros delitos contra la familia',
    'Other Thefts': 'Otros hurtos',
    'Prisoner Evasion': 'Fuga de presos',
    'Property Damage': 'Daños a la propiedad',
    'Public Space Robbery': 'Robo en espacio público',
    'Public Transportation Robbery': 'Robo en transporte público',
    'Sexual Abuse': 'Abuso sexual',
    'Sexual Bullying': 'Bullyng sexual',
    'Sexual Harassment': 'Acoso sexual',
    'Simple Rape': 'Violación',
    'Street Robbery': 'Robo en la calle',
    'Threats': 'Amenazas',
    'Unintentional Injury': 'Lesión no intencional'
}
df_analisis['Subtipo_delito']=df_analisis['Subtipo_delito'].map(Subtipo_delito)

Modalidad_delito = {
    '4-wheel car theft With violence': 'Robo de vehículo de 4 ruedas con violencia',
    '4-wheel car theft Without violence': 'Robo de vehículo de 4 ruedas sin violencia',
    'Abduction': 'Secuestro',
    'Abortion': 'Aborto',
    'Against the environment': 'Delitos contra el medio ambiente',
    'Breach of trust': 'Abuso de confianza',
    'Child trafficking': 'Trata de menores',
    'Corruption of minors': 'Corrupción de menores',
    'Crimes committed by public servants': 'Delitos cometidos por servidores públicos',
    'Dispossession': 'Despojo de bienes',
    'Drug dealing': 'Narcomenudeo',
    'Electoral crimes': 'Delitos electorales',
    'Equivalent rape': 'Violación equiparada',
    'Express kidnapping': 'Secuestro exprés',
    'Extortion': 'Extorsión',
    'Extortion kidnapping': 'Secuestro de extorsión',
    'Falsity': 'Falsedad',
    'Family violence': 'Violencia familiar',
    'Forgery': 'Falsificación',
    'Fraud': 'Fraude',
    'Gender violence in all its forms other than family violence': 'Violencia de género en todas sus formas, excepto la violencia familiar',
    'Housebreaking': 'Allanamiento de morada',
    'Human trafficking': 'Trata de personas',
    'In traffic accident': 'En accidente de tráfico',
    'Incest': 'Incesto',
    'Kidnapping to cause harm': 'Secuestro con fines de causar daño',
    'Kidnapping with hostage taking': 'Secuestro con toma de rehenes',
    'Motorcycle theft With violence': 'Robo de motocicleta con violencia',
    'Motorcycle theft Without violence': 'Robo de motocicleta sin violencia',
    'Non-compliance with family assistance obligations': 'Incumplimiento de obligaciones de manutención familiar',
    'Not specified': 'No especificado',
    'Other common-law crimes': 'Otros delitos comunes',
    'Other crimes against life and bodily integrity': 'Otros delitos contra la vida y la integridad corporal',
    'Other crimes against personal freedom': 'Otros delitos contra la libertad personal',
    'Other crimes against property': 'Otros delitos contra la propiedad',
    'Other crimes against sexual freedom and security': 'Otros delitos contra la libertad y seguridad sexual',
    'Other crimes against society': 'Otros delitos contra la sociedad',
    'Other crimes against the family': 'Otros delitos contra la familia',
    'Other types of kidnappings': 'Otros tipos de secuestros',
    'Prisoner evasion': 'Evasión de prisionero',
    'Property damage': 'Daño a la propiedad',
    'Sexual abuse': 'Abuso sexual',
    'Sexual bullying': 'Bullyng sexual',
    'Sexual harassment': 'Acoso sexual',
    'Simple rape': 'Violación',
    'Theft of cables, pipes, and other objects for public services With violence': 'Robo de cables, tuberías y otros objetos para servicios públicos Con violencia',
    'Theft of cables, pipes, and other objects for public services Without violence': 'Robo de cables, tuberías y otros objetos para servicios públicos Sin violencia',
    'Theft of industrial or agricultural tool With violence': 'Robo de herramienta industrial o agrícola Con violencia',
    'Theft of industrial or agricultural tool Without violence': 'Robo de herramienta industrial o agrícola Sin violencia',
    'Theft of small and large boats With violence': 'Robo de botes pequeños y grandes Con violencia',
    'Theft of small and large boats Without violence': 'Robo de botes pequeños y grandes Sin violencia',
    'Threats': 'Amenazas',
    'Tractor theft With violence': 'Robo de tractor Con violencia',
    'Tractor theft Without violence': 'Robo de tractor Sin violencia',
    'With another element': 'Con otro elemento',
    'With firearm': 'Con arma de fuego',
    'With sharp weapon': 'Con arma blanca',
    'With violence': 'Con violencia',
    'Without violence': 'Sin violencia'
}
df_analisis['Modalidad_delito']=df_analisis['Modalidad_delito'].map(Modalidad_delito)

Mes = {
    'January': 'Enero',
    'February':'Febrero',
    'March': 'Marzo',
    'April': 'Abril',
    'May': 'Mayo',
    'June': 'Junio',
    'July': 'Julio',
    'August': 'Agosto',
    'September': 'Septiembre',
    'November': 'Noviembre',
    'December': 'Diciembre'
}
df_analisis['Mes']=df_analisis['Mes'].map(Mes)

df_visualizacion = df_analisis.copy()
df_visualizacion.columns = df_visualizacion.columns.str.replace('_', ' ')
df_visualizacion
# Out:
#          Año  Id estado          Estado  \
# 0       2015          1  Aguascalientes
# 1       2015          1  Aguascalientes
# 2       2015          1  Aguascalientes
# 3       2015          1  Aguascalientes
# 4       2015          1  Aguascalientes
# ...      ...        ...             ...
# 332411  2022         32       Zacatecas
# 332412  2022         32       Zacatecas
# 332413  2022         32       Zacatecas
# 332414  2022         32       Zacatecas
# 332415  2022         32       Zacatecas
#
#                                    Bien juridico afectado  \
# 0                                Vida e integridad física
# 1                                Vida e integridad física
# 2                                Vida e integridad física
# 3                                Vida e integridad física
# 4                                Vida e integridad física
# ...                                                   ...
# 332411  Otros bienes jurídicos afectados (del fuero co...
# ...
